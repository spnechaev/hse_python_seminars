# %% [markdown]
# # Семинар 10. Асинхронное программирование

# %% [markdown]
# ## Цели
#
# После семинара вы сможете:
#
# - различать CPU-bound и I/O-bound задачи;
# - объяснять роли event loop, корутины, задачи и `await`;
# - конкурентно выполнять несколько I/O-операций через `asyncio.TaskGroup`;
# - находить блокирующий код и выбирать способ его изоляции.
#
# > **Формат:** справочный материал для индивидуального проекта. Отдельного задания по семинару нет.
#
# ## Перед началом
#
# Повторите функции и исключения. Для примеров нужен Python 3.11 или новее; HTTP-пример также требует `aiohttp` и подключения к интернету.

# %% [markdown]
# ## Полезные ссылки
#
# - [Python: корутины и задачи](https://docs.python.org/3/library/asyncio-task.html)
# - [Python: высокоуровневое API asyncio](https://docs.python.org/3/library/asyncio.html)
# - [aiohttp: Client Quickstart](https://docs.aiohttp.org/en/stable/client_quickstart.html)
#
# ## CPU-bound и I/O-bound задачи
#
# Характер нагрузки помогает выбрать инструмент конкурентности.
#
# | Тип нагрузки | На что уходит основное время | Примеры | Типичный подход |
# |---|---|---|---|
# | CPU-bound | Вычисления на процессоре | обработка изображений, сжатие, численные расчёты | процессы, специализированные библиотеки, профилирование и оптимизация |
# | I/O-bound | Ожидание сети, диска или внешнего сервиса | HTTP-запросы, драйвер БД, сокеты | `asyncio` с асинхронными библиотеками или потоки для блокирующего API |
#
# Конкурентность означает, что несколько задач продвигаются за один промежуток времени. Параллелизм означает, что несколько вычислений физически исполняются одновременно. `asyncio` в одном потоке даёт конкурентность: пока одна задача ждёт I/O, event loop запускает готовую к продолжению задачу.
#
# В обычной сборке CPython с GIL один поток процесса исполняет Python-байткод в конкретный момент. Для `asyncio` важнее другое ограничение: код между точками `await` выполняется без кооперативного переключения и может заблокировать весь event loop.
#
# ## Корутина, задача и await
#
# - `async def` объявляет корутинную функцию. Её вызов создаёт объект корутины, но сам по себе не запускает тело функции.
# - `await` ожидает другой awaitable-объект. Если результат ещё не готов, текущая корутина приостанавливается и возвращает управление event loop.
# - `asyncio.Task` планирует исполнение корутины конкурентно с другими задачами.
# - `asyncio.TaskGroup` объединяет связанные задачи: выход из блока ждёт их завершения, а ошибка одной задачи отменяет остальные и не оставляет их бесконтрольными.
#
# ## Как работает event loop
#
# ```text
# очередь готовых задач ──► event loop ──► выполняет задачу до следующего await
#         ▲                                      │
#         │                                      ▼
#         └──── завершение I/O ◄──── ОС / сеть / таймер
# ```
#
# Упрощённый цикл выглядит так:
#
# 1. Event loop выбирает готовую задачу.
# 2. Задача выполняется до завершения либо до точки, где ей приходится ждать.
# 3. Ожидаемая операция регистрируется, а управление получает другая готовая задача.
# 4. После завершения I/O исходная задача снова попадает в очередь готовых.
#
# `await` не делает синхронную функцию неблокирующей автоматически. Например, `time.sleep()`, обычный файловый API или тяжёлый цикл внутри `async def` по-прежнему останавливают event loop. Блокирующую I/O-функцию при необходимости можно перенести в рабочий поток:
#
# ```python
# result = await asyncio.to_thread(blocking_function, argument)
# ```
#
# Для CPU-bound вычислений `to_thread()` в обычной сборке CPython обычно не даёт параллельного исполнения Python-кода; здесь уместнее процессы или библиотека, которая выполняет вычисления вне GIL.
#
# ## Ошибки, отмена и тайм-ауты
#
# Сетевой запрос может зависнуть или завершиться ошибкой, поэтому внешние операции ограничивают по времени. В Python 3.11+ для произвольного асинхронного блока можно использовать `asyncio.timeout()`:
#
# ```python
# async with asyncio.timeout(5):
#     result = await slow_operation()
# ```
#
# Отмена доставляется задаче как `asyncio.CancelledError`. Ресурсы освобождают через контекстные менеджеры или `try/finally`; если исключение отмены перехвачено для очистки, его обычно нужно пробросить дальше.

# %% [markdown]
# ## Первая корутина
#
# В Jupyter event loop уже запущен, поэтому корутину можно ожидать через top-level `await`. В обычном `.py`-файле точкой входа служит `asyncio.run(main())`.

# %%
import asyncio


async def process_request(request: str) -> str:
    print(f"Started: {request}")
    await asyncio.sleep(0.1)
    return f"Processed {request}"


result = await process_request("aaa")
print(result)

# %% [markdown]
# ## Конкурентные HTTP-запросы
#
# Один `ClientSession` переиспользует пул соединений. `TaskGroup` запускает запросы конкурентно и гарантированно дожидается созданных задач. В примере ожидаемые сетевые ошибки преобразуются в результат отдельного запроса, поэтому недоступность одного адреса не отменяет остальные проверки.

# %%
import asyncio
import aiohttp


async def check(
    session: aiohttp.ClientSession, url: str
) -> tuple[str, int | str]:
    try:
        async with session.get(url) as response:
            response.raise_for_status()
            return url, response.status
    except (aiohttp.ClientError, TimeoutError) as error:
        return url, f"{type(error).__name__}: {error}"


async def check_all(websites: list[str]) -> list[tuple[str, int | str]]:
    timeout = aiohttp.ClientTimeout(total=5)
    async with aiohttp.ClientSession(timeout=timeout) as session:
        async with asyncio.TaskGroup() as group:
            tasks = [
                group.create_task(check(session, url))
                for url in websites
            ]
    return [task.result() for task in tasks]


websites = [
    "https://www.python.org",
    "https://docs.aiohttp.org",
    "https://example.com/not-found",
]
for url, result in await check_all(websites):
    print(f"{url}: {result}")

# %% [markdown]
# ## Блокирующий и неблокирующий вызов
#
# Обе функции объявлены через `async def`, но только `asyncio.sleep()` отдаёт управление event loop. Поэтому пять блокирующих ожиданий выполняются одно за другим, а пять неблокирующих ожиданий перекрываются по времени.

# %%
import asyncio
import time


DELAY = 0.2
CALL_COUNT = 5


async def blocking_sleep() -> None:
    time.sleep(DELAY)


async def nonblocking_sleep() -> None:
    await asyncio.sleep(DELAY)


async def measure(operation) -> float:
    start = time.perf_counter()
    async with asyncio.TaskGroup() as group:
        for _ in range(CALL_COUNT):
            group.create_task(operation())
    return time.perf_counter() - start


blocking_time = await measure(blocking_sleep)
nonblocking_time = await measure(nonblocking_sleep)
print(f"Blocking calls: {blocking_time:.2f} seconds")
print(f"Non-blocking calls: {nonblocking_time:.2f} seconds")

# %% [markdown]
# ## Где пригодится в индивидуальном проекте
#
# Асинхронность полезна, когда проект одновременно ожидает несколько независимых внешних операций: обращается к API, отправляет запросы к асинхронному драйверу БД или обслуживает много сетевых соединений. Она не ускорит тяжёлые вычисления сама по себе.
#
# При выборе библиотек важно не смешивать модели случайно: один блокирующий HTTP-клиент внутри `async def` остановит обработку остальных задач. Для каждого внешнего вызова нужны ограничение времени, обработка ошибок и понятная политика отмены. Число одновременно выполняемых запросов иногда дополнительно ограничивают семафором, чтобы не перегружать внешний сервис.

# %% [markdown]
# ## Самопроверка
#
# 1. Чем конкурентность отличается от параллелизма?
# 2. Почему вызов корутинной функции ещё не запускает её тело?
# 3. В какой момент корутина возвращает управление event loop?
# 4. Почему `time.sleep()` внутри `async def` блокирует остальные задачи?
# 5. Какие гарантии даёт `TaskGroup`, если одна из связанных задач завершается ошибкой?
# 6. Когда для блокирующей функции подходит `asyncio.to_thread()`, а когда нужны процессы?

# %% [markdown]
# ## Итоги
#
# - `asyncio` подходит прежде всего для конкурентных I/O-bound операций.
# - `await` создаёт точку кооперативного переключения только при ожидании незавершённой операции.
# - Блокирующий код останавливает event loop, даже если находится внутри `async def`.
# - `TaskGroup` задаёт явные границы жизни связанных задач и корректно обрабатывает их совместное завершение.
# - Тайм-ауты, отмена и освобождение ресурсов — обязательная часть надёжного асинхронного кода.
