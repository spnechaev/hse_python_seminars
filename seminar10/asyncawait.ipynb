# %% [markdown]
# # Семинар 10. Асинхронное программирование

# %% [markdown]
# ## Цели
#
# После семинара вы сможете:
#
# - различать CPU-bound и I/O-bound задачи;
# - объяснять работу event loop, coroutine и await;
# - конкурентно выполнять несколько I/O-операций через asyncio.
#
# > **Формат:** справочный материал для индивидуального проекта. Отдельного задания по семинару нет.
#
# ## Перед началом
#
# Повторите функции и исключения. Для HTTP-примера нужны aiohttp и интернет.

# %% [markdown]
# ### Полезные ссылки
#   * https://realpython.com/async-io-python/
#
# ### Введение и мотивация
# По характеру основной нагрузки программы часто делят на CPU-bound и I/O-bound. Вот основные различия:
#
# **CPU-bound программы**
#
# Определение: Программы, которые большую часть времени тратят на вычисления
# Характеристики:
#   * Высокая загрузка процессора (CPU utilization близок к 100%)
#   * Минимальное время ожидания
#   * Производительность зависит от мощности CPU
#
# Примеры:
#   * Математические вычисления
#   * Шифрование/дешифрование
#   * Обработка видео/аудио
#   * Сортировка больших массивов
#
# **I/O-bound программы**
# Определение: Программы, которые часто ожидают завершения операций ввода-вывода
# Характеристики:
#   * Низкая загрузка CPU
#   * Частые простои при ожидании диска/сети
#   * Производительность зависит от скорости ввода-вывода
#
# Примеры:
#   * Чтение/запись файлов
#   * Сетевые запросы
#   * Работа с базами данных
#   * Пользовательский ввод
#
# Рассмотрим конкурентную обработку нескольких запросов в I/O-bound программах на Python.
#
# ## GIL (Global Interpreter Lock)
# В стандартной сборке CPython GIL обычно позволяет только одному потоку одновременно исполнять Python-байткод в рамках процесса. Это ограничение не распространяется одинаково на все реализации Python и не мешает потокам быть полезными при ожидании ввода-вывода.
# Когда поток ожидает операцию ввода-вывода, интерпретатор может передать выполнение другому потоку.
#
# ## Подходы к параллельной обработке
# **Последовательная обработка**
#
# ```python
# for request in incoming_requests:
#     process_request(request):
#
# ```
# При длительных операциях запросы обрабатываются по одному и накапливаются в очереди. Это похоже на сеанс игры, в котором гроссмейстер завершает каждую партию целиком, прежде чем перейти к следующей.
#
# **Параллельная обработка**
#
# ```python
# import threading
#
# def process_request(request):
#     print(request)
#
# threads = []
# for request in incoming_requests:
#     t = threading.Thread(target=process_request, args=(request,))
#     threads.append(t)
#     t.start()
# ```
# Количество потоков ограничено ресурсами системы, а с их ростом увеличиваются накладные расходы на переключение. Потоки полезны для многих I/O-bound задач, но обычно не ускоряют исполнение CPU-bound Python-кода.
#
# **Асинхронная обработка**
#
# ```python
# import asyncio
#
# async def process_request(request):
#     print(request)
#
# async def main():
#     tasks = []
#     for request in incoming_requests:
#         tasks.append(asyncio.create_task(process_request(request)))
#     await asyncio.gather(*tasks)
#
#
# asyncio.run(main())
# ```
# В основе этого механизма лежит `event loop`: подход, когда программа в цикле определяет, не пора ли инициировать какую-то новую неблокирующую операцию и не пора ли сделать что-то с результатом завершенной операции, инициированной ранее. Сами операции не блокируют основной поток исполнения программы.
#
# **Конструкции Python для асинхронной обработки**
# `async` и `await` — ключевые слова:
# * `async` объявляет асинхронную функцию;
# * `await` приостанавливает текущую корутину до завершения ожидаемой операции.
#
# `asyncio` — стандартный модуль для асинхронного программирования.
#
# **Асинхронная функция**
# ```python
# async def process_request(request):
#     # здесь обычный код, с небольшой особенностью, нельзя использовать `yield from`. Не очень и хотелось
#     print(request)
#     # await - ожидает завершения асинхронной операции. Это сообщение системе, что пока эта операция не завершена, нет смысла продолжать, и можно переключиться на другую задачу
#     await asyncio.sleep(1)
#     return request
#
# ```

# %%
import asyncio

async def process_request(request):
    print(request)
    return f"Processed {request}"

# В Jupyter уже запущен event loop, поэтому можно использовать top-level await.
result = await process_request("aaa")
print(result)

# %%
import asyncio
import aiohttp

async def check(url, session):
    try:
        async with session.get(url) as response:
            print(f"{url}: status -> {response.status}")
    except (aiohttp.ClientError, asyncio.TimeoutError) as error:
        print(f"{url}: request failed -> {error}")


async def main():
    websites = [
        "https://realpython.com",
         "https://pycoders.com",
         "https://www.python.org",
         "https://example.com/not-found"
    ]
    timeout = aiohttp.ClientTimeout(total=5)
    async with aiohttp.ClientSession(timeout=timeout) as session:
        # gather дожидается конкурентного завершения всех задач
        await asyncio.gather(*(check(url, session) for url in websites))


await main()

# %%
import asyncio
import time

async def sync_sleep():
    time.sleep(1)

async  def async_sleep():
    await asyncio.sleep(1)

async def main():
    start = time.perf_counter()
    await asyncio.gather(
        # поскольку sync_sleep полностью синхронен, все 10 вызовов исполняются последовательно
        # никакого выигрыша по времени нет
        *(sync_sleep() for _ in range(10))
    )
    end = time.perf_counter()
    print(f"\n==> Blocking calls: {end - start:.2f} seconds")

    start = time.perf_counter()
    await asyncio.gather(
        # а здесь, поскольку внутри есть await, обработчик event loop может начать обработку следующей задачи, и выигрыш по времени есть
        *(async_sleep() for _ in range(10))
    )
    end = time.perf_counter()
    print(f"\n==> Async calls: {end - start:.2f} seconds")

if __name__ == "__main__":
    # asyncio.run(main())
    await main()
