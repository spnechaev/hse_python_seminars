# %% [markdown]
# # Семинар 11. Базы данных

# %% [markdown]
# ## Цели
#
# После семинара вы сможете:
#
# - объяснять назначение таблиц, ключей, транзакций и индексов;
# - писать базовые DDL- и DML-запросы;
# - связывать FastAPI с SQLite через SQLModel.
#
# > **Формат:** справочный материал для индивидуального проекта. Отдельного задания по семинару нет.
#
# ## Перед началом
#
# Понадобятся классы, HTTP и JSON. Для финального примера установите FastAPI, SQLModel и Uvicorn.

# %% [markdown]
# ## Полезные ссылки
#
# - [SQLAlchemy Unified Tutorial](https://docs.sqlalchemy.org/en/20/tutorial/)
# - [SQLAlchemy ORM Quick Start](https://docs.sqlalchemy.org/en/20/orm/quickstart.html)
# - [SQLModel: FastAPI и базы данных](https://sqlmodel.tiangolo.com/tutorial/fastapi/)
# - [FastAPI: lifespan](https://fastapi.tiangolo.com/advanced/events/)
# - [SQLite: документация языка SQL](https://www.sqlite.org/lang.html)

# %% [markdown]
# ## Зачем нужна база данных
# Приложению часто нужно сохранять состояние между запусками: учётные записи, историю покупок, складские остатки, результаты наблюдений или содержимое пользовательских публикаций. Для простого сценария данные можно записать в файл:
#
# ```python
# with open("file.txt", "w", encoding="utf-8") as file:
#     for result in results:
#         file.write(f"{result}\n")
# ```
#
# По мере роста приложения появляются дополнительные требования:
#
# - быстро находить и обновлять отдельные записи;
# - согласованно выполнять несколько связанных изменений;
# - поддерживать ограничения и связи между данными;
# - безопасно обслуживать параллельные запросы;
# - управлять восстановлением, резервным копированием и доступом.
#
# СУБД — система управления базами данных — предоставляет эти механизмы поверх физического хранения. В семинаре рассматриваются основные понятия реляционных баз и практическая интеграция SQLite с Python-приложением.

# %% [markdown]
# ## Реляционные и нереляционные БД
# В реляционной базе данные организованы в таблицы с заранее описанными столбцами. Строки связываются первичными и внешними ключами, а для описания схемы и запросов используется SQL. Ограничения `NOT NULL`, `UNIQUE`, `CHECK` и `FOREIGN KEY` помогают базе поддерживать целостность данных.
#
# Нереляционные СУБД используют другие модели: ключ—значение, документы, графы или широкие столбцы. Это не означает отсутствия структуры — структура и связи просто выражаются иначе и часто контролируются приложением. Выбор зависит от запросов, требований к согласованности, масштаба и характера данных.
#
# Далее рассматриваем реляционную модель и SQLite.

# %% [markdown]
# ## Транзакции
# Транзакция — это одна или несколько операций с данными, рассматриваемых как единое целое. Успешную транзакцию фиксируют командой `COMMIT`, а незавершённую или ошибочную отменяют через `ROLLBACK`.
#
# Аббревиатура ACID описывает четыре свойства транзакций:
#
# - **Atomicity — атомарность.** Выполняются либо все операции транзакции, либо ни одна.
# - **Consistency — согласованность.** Транзакция переводит базу из одного допустимого состояния в другое, не нарушая ограничения схемы.
# - **Isolation — изоляция.** Параллельные транзакции не должны видеть недопустимые промежуточные состояния. Конкретные гарантии зависят от уровня изоляции и СУБД.
# - **Durability — долговечность.** После успешного `COMMIT` изменения должны пережить сбой процесса или перезапуск системы в пределах гарантий СУБД.
#
# ```sql
# BEGIN;
# UPDATE accounts SET balance = balance - 100 WHERE id = 1;
# UPDATE accounts SET balance = balance + 100 WHERE id = 2;
# COMMIT;
# ```

# %% [markdown]
# ## SQL, DDL и DML
# SQL (Structured Query Language) — язык описания схемы и запросов к реляционным базам данных. Команды DDL создают и изменяют объекты базы, а DML читает и изменяет строки. В примерах ниже используется синтаксис SQLite.
#
# ```sql
# PRAGMA foreign_keys = ON;
#
# -- DDL: описываем таблицы и ограничения.
# CREATE TABLE users (
#     id INTEGER PRIMARY KEY,
#     name TEXT NOT NULL UNIQUE,
#     password_hash TEXT NOT NULL
# );
#
# CREATE TABLE posts (
#     id INTEGER PRIMARY KEY,
#     user_id INTEGER NOT NULL,
#     text TEXT NOT NULL CHECK (length(text) > 0),
#     FOREIGN KEY (user_id) REFERENCES users(id)
#         ON DELETE CASCADE
#         ON UPDATE CASCADE
# );
#
# -- DML: добавляем, читаем, обновляем и удаляем данные.
# INSERT INTO users (name, password_hash)
# VALUES ('user1', '<argon2id hash>');
#
# SELECT id, name FROM users;
# SELECT id, name FROM users WHERE name = 'user1';
#
# UPDATE users
# SET password_hash = '<new argon2id hash>'
# WHERE name = 'user1';
#
# DELETE FROM users WHERE name = 'user1';
# ```
#
# Пароли не хранят в открытом виде и не хешируют быстрыми алгоритмами общего назначения. Приложение должно использовать специализированный алгоритм хеширования паролей, например Argon2id. Значения из пользовательского ввода передают в запрос отдельно от SQL-текста:
#
# ```python
# cursor.execute("SELECT id, name FROM users WHERE id = ?", (user_id,))
# ```
#
# `UPDATE` или `DELETE` без `WHERE` затронет все строки таблицы. Перед изменением полезно выполнить `SELECT` с тем же условием, а само изменение — внутри транзакции.

# %% [markdown]
# ## NULL
# `NULL` — специальный маркер отсутствующего или неизвестного значения. SQL использует трёхзначную логику: `TRUE`, `FALSE` и `UNKNOWN`. Поэтому выражения `NULL = NULL`, `value = NULL` и `value != NULL` дают `UNKNOWN`, а `WHERE` оставляет только строки, для которых условие истинно.
#
# ```sql
# SELECT * FROM heroes WHERE age IS NULL;
# SELECT * FROM heroes WHERE age IS NOT NULL;
# SELECT name, COALESCE(age, 0) AS age_or_zero FROM heroes;
# ```
#
# `COALESCE` возвращает первое значение, которое не равно `NULL`. Подмена неизвестного возраста нулём уместна не всегда: смысл значения следует определить на уровне предметной области.

# %% [markdown]
# ## Виды JOIN
# `JOIN` связывает строки двух таблиц по условию после `ON`. Пусть в `users` есть Анна, Борис и Вера, у Анны два поста, у Бориса один, а у Веры ни одного.
#
# | Соединение | Какие строки попадут в результат | Что произойдёт с Верой |
# |---|---|---|
# | `INNER JOIN` | Только строки, для которых нашлась пара | Не попадёт в результат |
# | `LEFT JOIN` | Все строки левой таблицы и найденные пары справа | Попадёт один раз, поля поста будут `NULL` |
# | `RIGHT JOIN` | Все строки правой таблицы и найденные пары слева | Зависит от порядка таблиц; обычно понятнее переставить таблицы и использовать `LEFT JOIN` |
# | `FULL OUTER JOIN` | Все строки обеих таблиц | Попадёт, даже если пары нет |
#
# В связи «один ко многим» строка пользователя повторяется для каждого его поста.
#
# ```sql
# -- Только пользователи, у которых есть посты.
# SELECT users.name, posts.text
# FROM users
# INNER JOIN posts ON posts.user_id = users.id;
#
# -- Все пользователи, включая пользователей без постов.
# SELECT users.name, posts.text
# FROM users
# LEFT JOIN posts ON posts.user_id = users.id;
#
# -- Только пользователи без постов.
# SELECT users.id, users.name
# FROM users
# LEFT JOIN posts ON posts.user_id = users.id
# WHERE posts.id IS NULL;
# ```
#
# Первичный ключ `users.id` не бывает `NULL`, а ограничение `posts.user_id NOT NULL` требует автора для каждого поста. Внешний ключ дополнительно запрещает ссылаться на несуществующего пользователя. Эти ограничения фиксируют правила предметной области в самой базе.

# %% [markdown]
# ## Индексы
# Индекс — вспомогательная структура данных, которая ускоряет поиск, соединение и сортировку по определённым столбцам. Без подходящего индекса СУБД может просканировать всю таблицу (`full table scan`). Ограничения `PRIMARY KEY` и `UNIQUE` обычно создают необходимые индексы автоматически.
#
# ```sql
# -- Ускоряем поиск постов пользователя и JOIN по внешнему ключу.
# CREATE INDEX IF NOT EXISTS idx_posts_user_id ON posts (user_id);
#
# -- В SQLite можно посмотреть план выполнения запроса.
# EXPLAIN QUERY PLAN
# SELECT * FROM posts WHERE user_id = 1;
# ```
#
# Индексы занимают место и замедляют `INSERT`, `UPDATE` и `DELETE`, потому что их тоже приходится обновлять. Поэтому индексируют столбцы, которые действительно участвуют в частых запросах, а решение проверяют по плану выполнения и измерениям.

# %% [markdown]
# ## ORM
#
# ORM (Object–Relational Mapping) сопоставляет таблицы и связи с Python-классами. Она помогает собирать запросы, преобразовывать строки в объекты и управлять транзакциями, но не отменяет необходимость понимать SQL, ограничения и планы выполнения. Ниже используется современный стиль SQLAlchemy 2.x.
#
# ```python
# from __future__ import annotations
#
# from sqlalchemy import ForeignKey, String, create_engine, select
# from sqlalchemy.orm import (
#     DeclarativeBase,
#     Mapped,
#     Session,
#     mapped_column,
#     relationship,
# )
#
#
# class Base(DeclarativeBase):
#     pass
#
#
# class User(Base):
#     __tablename__ = "users"
#
#     id: Mapped[int] = mapped_column(primary_key=True)
#     name: Mapped[str] = mapped_column(String(255), unique=True, index=True)
#     password_hash: Mapped[str] = mapped_column(String(255))
#     posts: Mapped[list[Post]] = relationship(
#         back_populates="author",
#         cascade="all, delete-orphan",
#     )
#
#
# class Post(Base):
#     __tablename__ = "posts"
#
#     id: Mapped[int] = mapped_column(primary_key=True)
#     user_id: Mapped[int] = mapped_column(
#         ForeignKey("users.id", ondelete="CASCADE"),
#         index=True,
#     )
#     text: Mapped[str]
#     author: Mapped[User] = relationship(back_populates="posts")
#
#
# engine = create_engine("sqlite:///database.db")
# Base.metadata.create_all(engine)
#
# with Session(engine) as session:
#     statement = select(User).where(User.name == "user1")
#     user = session.scalars(statement).one_or_none()
#
#     posts_statement = (
#         select(Post)
#         .join(Post.author)
#         .where(User.name == "user1")
#     )
#     posts = session.scalars(posts_statement).all()
# ```
#
# `Session` задаёт границы работы с объектами и транзакцией. Для записи изменений нужны `session.add(...)` и `session.commit()`, а при ошибке — `session.rollback()`. В реальном приложении также важно следить за количеством запросов: ленивые связи могут привести к проблеме N+1.

# %% [markdown]
# ## FastAPI, SQLModel, SQLAlchemy и Pydantic: соединяем всё вместе
#
# Табличную модель отделяем от моделей входа и ответа. Так клиент не может передать серверный `id`, а `secret_name` не попадает в публичный ответ. Инициализацию приложения выполняем через `lifespan`.
#
# ```python
# from contextlib import asynccontextmanager
# from typing import Annotated
#
# from fastapi import Depends, FastAPI, HTTPException, Query, Response, status
# from sqlmodel import Field, SQLModel, Session, create_engine, select
#
#
# class HeroBase(SQLModel):
#     name: str = Field(index=True, min_length=1)
#     age: int | None = Field(default=None, ge=0)
#
#
# class Hero(HeroBase, table=True):
#     id: int | None = Field(default=None, primary_key=True)
#     secret_name: str
#
#
# class HeroCreate(HeroBase):
#     secret_name: str
#
#
# class HeroPublic(HeroBase):
#     id: int
#
#
# class HeroUpdate(SQLModel):
#     name: str | None = Field(default=None, min_length=1)
#     age: int | None = Field(default=None, ge=0)
#     secret_name: str | None = None
#
#
# sqlite_file_name = "database.db"
# sqlite_url = f"sqlite:///{sqlite_file_name}"
# connect_args = {"check_same_thread": False}
# engine = create_engine(sqlite_url, connect_args=connect_args)
#
#
# def create_db_and_tables() -> None:
#     SQLModel.metadata.create_all(engine)
#
#
# def get_session():  # одна сессия на запрос
#     with Session(engine) as session:
#         yield session
#
#
# SessionDep = Annotated[Session, Depends(get_session)]
#
#
# @asynccontextmanager
# async def lifespan(app: FastAPI):
#     create_db_and_tables()
#     yield
#
#
# app = FastAPI(lifespan=lifespan)
#
#
# @app.post(
#     "/heroes/",
#     response_model=HeroPublic,
#     status_code=status.HTTP_201_CREATED,
# )
# def create_hero(hero: HeroCreate, session: SessionDep) -> Hero:
#     db_hero = Hero.model_validate(hero)
#     session.add(db_hero)
#     session.commit()
#     session.refresh(db_hero)
#     return db_hero
#
#
# @app.get("/heroes/", response_model=list[HeroPublic])
# def read_heroes(
#     session: SessionDep,
#     offset: Annotated[int, Query(ge=0)] = 0,
#     limit: Annotated[int, Query(ge=1, le=100)] = 100,
# ) -> list[Hero]:
#     statement = select(Hero).offset(offset).limit(limit)
#     return list(session.exec(statement).all())
#
#
# @app.get("/heroes/{hero_id}", response_model=HeroPublic)
# def read_hero(hero_id: int, session: SessionDep) -> Hero:
#     hero = session.get(Hero, hero_id)
#     if hero is None:
#         raise HTTPException(status_code=404, detail="Hero not found")
#     return hero
#
#
# @app.patch("/heroes/{hero_id}", response_model=HeroPublic)
# def update_hero(
#     hero_id: int, hero: HeroUpdate, session: SessionDep
# ) -> Hero:
#     db_hero = session.get(Hero, hero_id)
#     if db_hero is None:
#         raise HTTPException(status_code=404, detail="Hero not found")
#     update_data = hero.model_dump(exclude_unset=True)
#     db_hero.sqlmodel_update(update_data)
#     session.add(db_hero)
#     session.commit()
#     session.refresh(db_hero)
#     return db_hero
#
#
# @app.delete("/heroes/{hero_id}", status_code=status.HTTP_204_NO_CONTENT)
# def delete_hero(hero_id: int, session: SessionDep) -> Response:
#     hero = session.get(Hero, hero_id)
#     if hero is None:
#         raise HTTPException(status_code=404, detail="Hero not found")
#     session.delete(hero)
#     session.commit()
#     return Response(status_code=status.HTTP_204_NO_CONTENT)
#
# ```
#
# `create_all()` удобно для первого учебного прототипа. При изменении схемы существующего проекта применяют миграции, например Alembic, а не пересоздают таблицы вручную.

# %% [markdown]
# ## Где пригодится в индивидуальном проекте
#
# База данных нужна, если состояние проекта должно сохраняться между запусками: пользователи, настройки, каталог, события или результаты вычислений. До реализации полезно определить сущности, связи и ограничения, а затем отделить HTTP-модели от табличных. Запросы к базе лучше сосредоточить в отдельном слое, чтобы обработчики API не отвечали одновременно за валидацию, SQL и бизнес-правила.
#
# Для небольшого локального прототипа подходит SQLite. Если появляются несколько экземпляров приложения, высокая параллельная нагрузка или эксплуатационные требования, выбор СУБД нужно пересмотреть отдельно.

# %% [markdown]
# ## Самопроверка
#
# 1. Какие ограничения следует задать для обязательного уникального имени пользователя?
# 2. Почему `WHERE field = NULL` не находит строки с отсутствующим значением?
# 3. Чем результат `INNER JOIN` отличается от `LEFT JOIN` для пользователя без постов?
# 4. Почему индекс ускоряет не все запросы и имеет собственную стоимость?
# 5. Зачем разделять табличную модель, модель создания и публичную модель ответа API?

# %% [markdown]
# ## Итоги
#
# - Схема и ограничения фиксируют допустимое состояние данных.
# - Транзакция объединяет связанные изменения и позволяет подтвердить или отменить их вместе.
# - `JOIN` связывает таблицы, а тип соединения определяет, сохранятся ли строки без пары.
# - Индексы ускоряют выбранные операции чтения ценой места и более дорогой записи.
# - ORM и SQLModel упрощают интеграцию с Python, но понимание SQL и границ транзакций остаётся необходимым.
